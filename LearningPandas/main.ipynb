# %% [markdown]
# # Pandas For Data Manipulation and Analysis

# %% [markdown]
# !["Pandas"](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png)

# %%
import numpy as np
import pandas as pd

# %%
#For Test:
A = np.array([1,2,3])
B = np.array([4,5,6])

df = pd.DataFrame(A, B)
df
# Out:
#    0
# 4  1
# 5  2
# 6  3

# %%
# Reading Data From Files:
    # 1. df = pd.read_excel('data.xlsx')
    # 2. df = pd.read_sql('data.sql')
    # 3. df = pd.read_csv('data.xlsx')

# %%
df = pd.read_csv("./Superstore.csv")
df
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 1          2  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 2          3  CA-2016-138688   12/06/16  16/06/16    Second Class    DV-13045
# 3          4  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# 4          5  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2014-110422   21/01/14  23/01/14    Second Class    TB-21400
# 9990    9991  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9991    9992  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9992    9993  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   04/05/17  09/05/17    Second Class    CC-12220
#
# ...

# %%
df.head()
df.head(20)
# Out:
#     Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 1        2  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 2        3  CA-2016-138688   12/06/16  16/06/16    Second Class    DV-13045
# 3        4  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# 4        5  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# 5        6  CA-2014-115812   09/06/14  14/06/14  Standard Class    BH-11710
# 6        7  CA-2014-115812   09/06/14  14/06/14  Standard Class    BH-11710
# 7        8  CA-2014-115812   09/06/14  14/06/14  Standard Class    BH-11710
# 8        9  CA-2014-115812   09/06/14  14/06/14  Standard Class    BH-11710
# 9       10  CA-2014-115812   09/06/14  14/06/14  Standard Class    BH-11710
# 10      11  CA-2014-115812   09/06/14  14/06/14  Standard Class    BH-11710
# ...

# %%
df.tail()
df.tail(10)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 9984    9985  CA-2015-100251   17/05/15  23/05/15  Standard Class    DV-13465
# 9985    9986  CA-2015-100251   17/05/15  23/05/15  Standard Class    DV-13465
# 9986    9987  CA-2016-125794   29/09/16  03/10/16  Standard Class    ML-17410
# 9987    9988  CA-2017-163629   17/11/17  21/11/17  Standard Class    RA-19885
# 9988    9989  CA-2017-163629   17/11/17  21/11/17  Standard Class    RA-19885
# 9989    9990  CA-2014-110422   21/01/14  23/01/14    Second Class    TB-21400
# 9990    9991  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9991    9992  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9992    9993  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   04/05/17  09/05/17    Second Class    CC-12220
#
#          Customer Name    Segment        Country         City  ...  \
# ...

# %%
df["Category"]
# Out:
# 0             Furniture
# 1             Furniture
# 2       Office Supplies
# 3             Furniture
# 4       Office Supplies
#              ...
# 9989          Furniture
# 9990          Furniture
# 9991         Technology
# 9992    Office Supplies
# 9993    Office Supplies
# Name: Category, Length: 9994, dtype: object

# %%
df["Sales"][9:16:2] # Start End Gap
# Out:
# 9     114.900
# 11    911.424
# 13    407.976
# 15      2.544
# Name: Sales, dtype: float64

# %%
df["Sales"] > 200
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991     True
# 9992    False
# 9993     True
# Name: Sales, Length: 9994, dtype: bool

# %%
df["Sales"][df["Sales"] > 200]
# Out:
# 0        261.9600
# 1        731.9400
# 3        957.5775
# 7        907.1520
# 10      1706.1840
#           ...
# 9976     249.5840
# 9979     437.4720
# 9988     206.1000
# 9991     258.5760
# 9993     243.1600
# Name: Sales, Length: 2579, dtype: float64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df["Category"].count()
# Out:
# 9994

# %%
df["Sales"].max()
df["Sales"].min()
df["Sales"].sum()
df["Sales"].median()
df["Sales"].mean()
df["Sales"].std()
# Out:
# 623.2451005086807

# %%
df.isna()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
df["Sales"].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Sales, Length: 9994, dtype: bool

# %%
df["Sales"].isna().any()
# Out:
# False

# %%
df["Sales"].isna().sum()
# Out:
# 0

# %%
# df["Sales"].fillna(0)
# df["Sales"].fillna("")
# df["Sales"].fillna(df["Sales"].mean())

# %%
df.dropna()
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 1          2  CA-2016-152156   08/11/16  11/11/16    Second Class    CG-12520
# 2          3  CA-2016-138688   12/06/16  16/06/16    Second Class    DV-13045
# 3          4  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# 4          5  US-2015-108966   11/10/15  18/10/15  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2014-110422   21/01/14  23/01/14    Second Class    TB-21400
# 9990    9991  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9991    9992  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9992    9993  CA-2017-121258   26/02/17  03/03/17  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   04/05/17  09/05/17    Second Class    CC-12220
#
# ...

# %%
df = df.fillna(0)
df.fillna(0, inplace= True)

# %%
df.loc[0] # The First Row
# Out:
# Row ID                                           1
# Order ID                            CA-2016-152156
# Order Date                                08/11/16
# Ship Date                                 11/11/16
# Ship Mode                             Second Class
# Customer ID                               CG-12520
# Customer Name                          Claire Gute
# Segment                                   Consumer
# Country                              United States
# City                                     Henderson
# State                                     Kentucky
# Postal Code                                  42420
# Region                                       South
# Product ID                         FUR-BO-10001798
# Category                                 Furniture
# Sub-Category                             Bookcases
# Product Name     Bush Somerset Collection Bookcase
# Sales                                       261.96
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Order Date"]
# Out:
# /var/folders/nn/p8hlssl928zct0_lyyc81s8c0000gn/T/ipykernel_55316/558843909.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Order Date"] = pd.to_datetime(df["Order Date"])
# 0      2016-08-11
# 1      2016-08-11
# 2      2016-12-06
# 3      2015-11-10
# 4      2015-11-10
#           ...
# 9989   2014-01-21
# 9990   2017-02-26
# 9991   2017-02-26
# 9992   2017-02-26
# 9993   2017-04-05
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
df["Order Date"] = df["Order Date"].dropna()
df.dropna(subset=['Order Date'], inplace = True)

# %%
df.loc[7, 'Sales'] = 45

# %%
df.loc[6]
# Out:
# Row ID                             7
# Order ID              CA-2014-115812
# Order Date       2014-09-06 00:00:00
# Ship Date                   14/06/14
# Ship Mode             Standard Class
# Customer ID                 BH-11710
# Customer Name        Brosina Hoffman
# Segment                     Consumer
# Country                United States
# City                     Los Angeles
# State                     California
# Postal Code                    90032
# Region                          West
# Product ID           OFF-AR-10002833
# Category             Office Supplies
# Sub-Category                     Art
# Product Name              Newell 322
# Sales                           7.28
# Quantity                           4
# Discount                         0.0
# Profit                        1.9656
# Name: 6, dtype: object

# %%
df["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
# for x in df.index:
#   if df.loc[x, "Sales"] > 120:
#     df.loc[x, "Sales"] = 120

# %%
df["Sales"]
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
# for x in df.index:
#   if df.loc[x, "Sales"] >= 120:
#     df.drop(x,inplace = True)

# %%
df["Region"]
# Out:
# 0       South
# 1       South
# 2        West
# 3       South
# 4       South
#         ...
# 9989    South
# 9990     West
# 9991     West
# 9992     West
# 9993     West
# Name: Region, Length: 9994, dtype: object

# %%
df["Region"].duplicated()
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 9989     True
# 9990     True
# 9991     True
# 9992     True
# 9993     True
# Name: Region, Length: 9994, dtype: bool

# %%
# for i in range(len(df["Region"].duplicated())):
#     if df["Region"].duplicated()[i]:
#         df.drop(i, inplace = True)

# %%
df
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2016-152156 2016-08-11  11/11/16    Second Class    CG-12520
# 1          2  CA-2016-152156 2016-08-11  11/11/16    Second Class    CG-12520
# 2          3  CA-2016-138688 2016-12-06  16/06/16    Second Class    DV-13045
# 3          4  US-2015-108966 2015-11-10  18/10/15  Standard Class    SO-20335
# 4          5  US-2015-108966 2015-11-10  18/10/15  Standard Class    SO-20335
# ...      ...             ...        ...       ...             ...         ...
# 9989    9990  CA-2014-110422 2014-01-21  23/01/14    Second Class    TB-21400
# 9990    9991  CA-2017-121258 2017-02-26  03/03/17  Standard Class    DB-13060
# 9991    9992  CA-2017-121258 2017-02-26  03/03/17  Standard Class    DB-13060
# 9992    9993  CA-2017-121258 2017-02-26  03/03/17  Standard Class    DB-13060
# 9993    9994  CA-2017-119914 2017-04-05  09/05/17    Second Class    CC-12220
#
# ...

# %%
df["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
len(df["Sub-Category"].unique())
# Out:
# 17

# %%
len(df["Sub-Category"])
# Out:
# 9994

# %%
len(df["Sub-Category"].duplicated())
# Out:
# 9994

# %%
df["Sub-Category"].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df["Sales"].map(lambda i: i - df["Sales"]*0.2)
# Out:
# 0       0       209.5680
# 1       115.5720
# 2       259....
# 1       0       679.5480
# 1       585.5520
# 2       729....
# 2       0       -37.7720
# 1      -131.7680
# 2        11....
# 3       0       905.1855
# 1       811.1895
# 2       954....
# 4       0       -30.0240
# 1      -124.0200
# 2        19....
#                               ...
# 9989    0       -27.1440
# 1      -121.1400
# 2        22....
# 9990    0       39.5680
# 1      -54.4280
# 2       89.036...
# 9991    0       206.1840
# 1       112.1880
# 2       255....
# 9992    0       -22.7920
# 1      -116.7880
# 2        26....
# 9993    0       190.7680
# 1        96.7720
# 2       240....
# Name: Sales, Length: 9994, dtype: object

# %%
df.groupby("Category").count()
# Out:
#                  Row ID  Order ID  Order Date  Ship Date  Ship Mode  \
# Category
# Furniture          2121      2121        2121       2121       2121
# Office Supplies    6026      6026        6026       6026       6026
# Technology         1847      1847        1847       1847       1847
#
#                  Customer ID  Customer Name  Segment  Country  City  State  \
# Category
# Furniture               2121           2121     2121     2121  2121   2121
# Office Supplies         6026           6026     6026     6026  6026   6026
# Technology              1847           1847     1847     1847  1847   1847
#
#                  Postal Code  Region  Product ID  Sub-Category  Product Name  \
# Category
# Furniture               2121    2121        2121          2121          2121
# Office Supplies         6026    6026        6026          6026          6026
# Technology              1847    1847        1847          1847          1847
#
# ...

# %%
df.sort_values(by="Sales")
df.sort_values(by="Sales",ascending=False)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 2697    2698  CA-2014-145317 2014-03-18  23/03/14  Standard Class    SM-20320
# 6826    6827  CA-2016-118689 2016-02-10  09/10/16  Standard Class    TC-20980
# 8153    8154  CA-2017-140151 2017-03-23  25/03/17     First Class    RB-19360
# 2623    2624  CA-2017-127180 2017-10-22  24/10/17     First Class    TA-21385
# 4190    4191  CA-2017-166709 2017-11-17  22/11/17  Standard Class    HL-15040
# ...      ...             ...        ...       ...             ...         ...
# 2106    2107  US-2014-152723 2014-09-26  26/09/14        Same Day    HG-14965
# 4711    4712  CA-2014-112403 2014-03-31  31/03/14        Same Day    JO-15280
# 8658    8659  CA-2016-168361 2016-06-21  25/06/16  Standard Class    KB-16600
# 9292    9293  CA-2017-124114 2017-02-03  02/03/17        Same Day    RS-19765
# 4101    4102  US-2017-102288 2017-06-19  23/06/17  Standard Class    ZC-21910
#
# ...

# %%
df["Customer Name"].replace("Chris Cortes", "Karn", inplace=True)
df["Customer Name"]
# Out:
# 0            Claire Gute
# 1            Claire Gute
# 2        Darrin Van Huff
# 3         Sean O'Donnell
# 4         Sean O'Donnell
#               ...
# 9989    Tom Boeckenhauer
# 9990         Dave Brooks
# 9991         Dave Brooks
# 9992         Dave Brooks
# 9993                Karn
# Name: Customer Name, Length: 9994, dtype: object

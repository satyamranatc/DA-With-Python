# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array(["A","B","C","D","E"])
y = np.array([1,2,3,4,5])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("My-Graph")
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("My-Graph")
plt.grid()
plt.show()

# %%
plt.plot(x,y,color = "red")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("My-Graph")
plt.grid()
plt.show()

# %%
plt.plot(x,y,ls= ":")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("My-Graph")
plt.grid()
plt.show()

"""
plt.plot(x,y,ls= ":")

Solid	  | 'solid'   | '-'  or None
Dashed	  | 'dashed'  | '--'
Dash-Dot  |	'dashdot' | '-.'
Dotted	  | 'dotted'  | ':'
No Line	  | 'None'	  | ''   or ' '

"""
# Out:
# '\nplt.plot(x,y,ls= ":")\n\nSolid\t  | \'solid\'   | \'-\'  or None\nDashed\t  | \'dashed\'  | \'--\'\nDash-Dot  |\t\'dashdot\' | \'-.\'\nDotted\t  | \'dotted\'  | \':\'\nNo Line\t  | \'None\'\t  | \'\'   or \' \'\n\n'

# %%
x = np.array(["A","B","C","D","E"])
y = np.array([1,2,2,7,5])
plt.plot(x,y,linewidth = "2.5",marker = 'o', ms = 10, mec = 'g',mfc = 'r')

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("My-Graph")
plt.grid()
plt.show()



# ----Markers------
# 'o'	Circle	
# '*'	Star	
# '.'	Point	
# ','	Pixel	
# 'x'	X	
# 'X'	X (filled)	
# '+'	Plus	
# 'P'	Plus (filled)	
# 's'	Square	
# 'D'	Diamond	
# 'd'	Diamond (thin)	
# 'p'	Pentagon	
# 'H'	Hexagon	
# 'h'	Hexagon	
# 'v'	Triangle Down	
# '^'	Triangle Up	
# '<'	Triangle Left	
# '>'	Triangle Right	
# '1'	Tri Down	
# '2'	Tri Up	
# '3'	Tri Left	
# '4'	Tri Right	
# '|'	Vline	
# '_'   Hline

# %%
x = np.array(["A","B","C","D","E"])
y = np.array([1,2,3,4,5])
# plt.bar(x,y, width=0.1)
plt.barh(x,y, height=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
X = np.array([1,2,3,14,5,6,17,8,91,110])
Y = np.array([3,2,1,4,2,1,5,1,6,7])
plt.scatter(X,Y,color='red', label='Data Set 1')

X2 = np.array([11,21,31,41,5,61,71,8,19,110])
Y2 = np.array([31,21,11,41,2,11,51,11,16,17])


plt.scatter(X2,Y2,color='blue', label='Data Set 2')
plt.legend()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='Blues')
plt.colorbar()

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

# sizes = []
# for i in range(len(x)):
#     sizes.append(x[i]+y[i])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
x = np.array([10,20,15,5])
plt.pie(x,labels = mylabels)
plt.legend()
plt.show()

# %%
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

x = np.array([10,20,15,5])

myexplode = [0.2, 0, 0, 0]


plt.pie(x,labels = mylabels,startangle=90,explode=myexplode,shadow = True)

plt.legend(title = "Four Fruits:")

plt.show()
